# %%
import numpy as np 
from brian2tools import *
from tools.functions import *
from tools.srbm_reconstruction_mnist import *
import matplotlib.pyplot as plt
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
""" date = '2023-04-13' # working pretty well
time = '23-12' """

date = '2023-04-19'
time = '14-19'
path = "output_mnist/"

W, Wvh, Wch, mBv, mBh, b_c, b_v, b_h, mB = load_matrices(date, time, path=path)
# Out:
# Matrices loaded from output/output_mnist/2023-04-19/14-19//

# %%
data =  mnist_data = load_MNIST(n_samples = 1, min_p = 1e-4, max_p = .9999, binary = True, seed = None)

# %%
test_data = mnist_data[4][0:100]
test_labels = mnist_data[5][0:100]
print(test_data.shape)
print(test_labels.shape)
# Out:
# (100, 784)
# (100,)

# %%
classification_free_energy(Wvh, Wch, b_h, b_c, test_data, test_labels, n_c_unit, n_classes = 10)
# Out:
# (0.82,
#  array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True, False,  True, False,  True, False,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True, False,  True,  True,  True,  True,  True,
#         False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True, False,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True, False,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True]))

# %%
hacked_digit = create_single_Id(idx = 3, data = data, N_v = N_v, N_c = N_c, n_c_unit = n_c_unit, 
                                beta_parameter = beta_parameter, mult_class=0.0,mult_data=1.0)
hacked_digit[:N_v].reshape(28,28)[:,:14] = 0.
cl = np.zeros(N_c)
cl[int(3*n_c_unit):int(4*n_c_unit)] = .98
cl[int(6*n_c_unit):int(7*n_c_unit)] = .98
hacked_digit[N_v:]= clamped_input_transform(cl, min_p = 1e-16, max_p = .500+.2e-9)

Ids_demo = np.load('data/ids.npy')
Ids = np.column_stack([
    create_single_Id(3, data, N_v = N_v, N_c = N_c, n_c_unit = n_c_unit, 
                    beta_parameter = beta_parameter, 
                    mult_class = 0.0, mult_data = 1.0) * 0,
    create_single_Id(2, data, N_v = N_v, N_c = N_c, n_c_unit = n_c_unit, 
                    beta_parameter = beta_parameter, 
                    mult_class = 0.0, mult_data = 1.0),
    create_single_Id(5, data, N_v = N_v, N_c = N_c, n_c_unit = n_c_unit, 
                    beta_parameter = beta_parameter, 
                    mult_class = 1.0, mult_data = 0.0),
    hacked_digit,
    ]).T

#Ids[-1,:N_v] = Ids_demo[-1,:N_v]
#Ids[1,:N_v] = Ids_demo[1,:N_v]

# %%
out = main(W, b_v, b_c, b_h, Id = Ids, monitors = True)
Mh, Mv, Mc= out['Mh'], out['Mv'], out['Mc']
# Out:
# Creating equation
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_a_8s0s4_/flag_test.o -w
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ocp3s2ys/flag_test.o -O3
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_p4a2czqb/flag_test.o -ffast-math
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_ec8apxxp/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_kbd2k9bm/flag_test.o -march=native
# WARNING    Removing unsupported flag '-march=native' from compiler flags. [brian2.codegen.cpp_prefs]
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders/07
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T
# INFO:root:creating /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -arch arm64 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -D_FORTIFY_SOURCE=2 -isystem /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/include -c /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/flag_test.cpp -o /var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/var/folders/07/kzl97fv95b7d6cv_kvm50vc80000gn/T/brian_flag_test_s5ngzzn7/flag_test.o -std=c++11
# INFO       No numerical integration method specified for group 'neurongroup_1', using method 'euler' (took 0.02s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'neurongroup', using method 'euler' (took 0.01s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# 1.1607608795166016

# %%
plot_id1=np.array(Ids[1][0:784]).reshape(28,28)
plot_id2=np.array(Ids[2][0:784]).reshape(28,28)
plot_id3=np.array(Ids[3][0:784]).reshape(28,28)

fig, (axs1, axs2, axs3) = plt.subplots(1, 3)
axs1.imshow(plot_id1, interpolation = 'bicubic')
axs2.imshow(plot_id2, interpolation = 'bicubic') 
axs3.imshow(plot_id3, interpolation = 'bicubic')

# %%
input = np.array(spike_histogram(Mv,T1_s+10*t_ref,T1_e)).T[1].reshape(28,28)
dream = np.array(spike_histogram(Mv,T2_s+60*t_ref,T2_e)).T[1].reshape(28,28)
completion = np.array(spike_histogram(Mv,T3_s+15*t_ref,T3_e)).T[1].reshape(28,28)


fig, (axs1, axs2, axs3) = plt.subplots(1, 3)
axs1.imshow(input, interpolation = 'bicubic')
axs2.imshow(dream, interpolation = 'bicubic')
axs3.imshow(completion, interpolation = 'bicubic')

# %%
plot_raster(Mc.i, Mc.t, markersize=2,marker='|', color='k', mew=1)
for i in range(n_classes):
    axhline(-0.6+float(i)*4, color='k')
axvline(T1_s/second*1000, color='k')
axvline(T1_e/second*1000, color='k')
axvline(T2_s/second*1000, color='k')
axvline(T2_e/second*1000, color='k')
axvline(T3_s/second*1000, color='k')
axvline(T3_e/second*1000, color='k')
# Out:
# WARNING    /opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/lib/python3.9/site-packages/brian2tools/plotting/data.py:59: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "." (-> marker='.'). The keyword argument will take precedence.
#   axes.plot(spike_times/time_unit, spike_indices, '.', **kwds)
#  [py.warnings]
# WARNING:py.warnings:/opt/homebrew/Caskroom/miniconda/base/envs/jupyt-tf/lib/python3.9/site-packages/brian2tools/plotting/data.py:59: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "." (-> marker='.'). The keyword argument will take precedence.
#   axes.plot(spike_times/time_unit, spike_indices, '.', **kwds)

# %%
plot_raster(Mv.i, Mv.t, markersize=2,marker='|', color='k', mew=1)
axvline(T1_s/second*1000, color='k')
axvline(T1_e/second*1000, color='k')
axvline(T2_s/second*1000, color='k')
axvline(T2_e/second*1000, color='k')
axvline(T3_s/second*1000, color='k')
axvline(T3_e/second*1000, color='k')
